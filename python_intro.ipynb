# %% [markdown]
# # Intro to coding best practices in Python
# Created for the Refficiency group away weekend in 2021. Contact lshc3@cam.ac.uk for any queries. This demonstration covers the key elements of coding we need to save the world via Resource Efficiency: loading data, visualising data, using functions.
#
# Key points for coding:
#
#
# 1.   Always think about clarity -> comment, comment, comment: if you win the lottery and move to Barbados tomorrow, someone else (or you in 3 years time once you've spent the money) needs to pick up your work.
# 2.   Start easy -> visualise your data, then think about most appropriate processing steps.
# 3.   Keep code flexible -> Use functions that perform standard tasks well, this will save you A LOT of time.

# %% [markdown]
# ## 1 - Functions
# An admittedly unconventional intro to coding but functions are so key to software development that let's give you a clear understanding of what they do.

# %%
"""Example of a simple script"""

# Input - Variable definition
qty_apples = 4
price_apple = 0.45

# Processing - Total cost calculation
cost_total = qty_apples*price_apple#complete here

# Output - Print to screen
print(cost_total)
# Out:
# 1.8

# %%
"""Definition of function"""

def cost_calculation(qty,price):
  """This function multiplies the quantity of items
  by the unit prices and prints total cost.

  Inputs
  qty - item quantity
  price - unit price

  Outputs
  Total cost print to screen
  """
  # Calculation
  cost = qty*price
  # Output
  print(cost_total)

# %%
"""Use function - type cost_calculation( and follow the instructions"""
cost_calculation(qty_apples,price_apple)#complete here
# Out:
# 1.8

# %% [markdown]
# Ok so that is a very basic function. Functions often (usually) do not sit within the script we are running. Run the next cell to clone the coding-tutorials Github repository which has a Python file containing functions. Then double-click on demo_functions.py in the file list on the left to visualise it.

# %%
! git clone "https://github.com/Resource-Efficiency-Collective/coding-tutorials.git" # Clone repo
# %cd coding-tutorials/ # Change working directory to repo
# Out:
# Cloning into 'coding-tutorials'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.

# %%
"""Now let's use the function contained in the python file to calculate cost""" 
import demo_functions as demfun
demfun.cost_print(qty_apples,price_apple)
